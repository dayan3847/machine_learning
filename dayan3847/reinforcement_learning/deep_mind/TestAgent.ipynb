# %%
import numpy as np
from Agent import KnowledgeModel
# Out:
# 2023-11-03 09:07:48.512124: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-03 09:07:48.543560: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-03 09:07:48.544013: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-03 09:07:49.076017: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
count_actions: int = 11  # cantidad de acciones
frames_shape: tuple = (100, 100,3)  # shape de los frames
frames_count: int = 4  # cantidad de frames que va a tener el estado

# %%
k = KnowledgeModel(count_actions, frames_shape, frames_count)

# %%
k.model_encoder.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 106, 106, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 50, 50, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 50, 50, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 50, 50, 64)   0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 52, 52, 64)   0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 25, 25, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 25, 25, 64)   4160        ['pool1_pool[0][0]']
#
# ...

# %%
k.model_learning.summary()
# Out:
# Model: "MY_Q_NET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  state_input (InputLayer)       [(None, 4, 4, 4, 20  0           []
#                                 48)]
#
#  state_flatten (Flatten)        (None, 131072)       0           ['state_input[0][0]']
#
#  action_input (InputLayer)      [(None, 11)]         0           []
#
#  state_zip (Dense)              (None, 5)            655365      ['state_flatten[0][0]']
#
#  action_zip (Dense)             (None, 5)            60          ['action_input[0][0]']
#
#  concatenate_action_state (Conc  (None, 10)          0           ['state_zip[0][0]',
#  atenate)                                                         'action_zip[0][0]']
#
#  q (Dense)                      (None, 1)            11          ['concatenate_action_state[0][0]'
# ...

# %%
4* 4*2048
# Out:
# 32768

# %%
8* 10*2048
# Out:
# 163840
