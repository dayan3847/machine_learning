# %%
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.set_title("Title")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.plot([1, 2, 3], [1, 2, 9], c="r", label="line1")

plt.tight_layout()
fig.show()
# Out:
# /tmp/ipykernel_19944/1190720996.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
