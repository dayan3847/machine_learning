# %%
from src.StochasticGradientDescentSinusoidal import StochasticGradientDescentSinusoidal

stochastic_gradient_descent = StochasticGradientDescentSinusoidal()

# %%
# Generate Data Points
stochastic_gradient_descent.m = 100  # Artificial Count
stochastic_gradient_descent.generate_data_points()
stochastic_gradient_descent.plot_data()

# %%
# Polynomial Degree
stochastic_gradient_descent.d = 10
stochastic_gradient_descent.generate_initial_parameters()
stochastic_gradient_descent.plot_data(initial=True)

# %%
# Config
stochastic_gradient_descent.a = .1
stochastic_gradient_descent.iterations_count = 5000
stochastic_gradient_descent.run(plot=False)

# %%
stochastic_gradient_descent.update_graphics()
stochastic_gradient_descent.plot_data_all()

# %%
stochastic_gradient_descent.print_repo()
# Out:
# REPORT
# Alpha: 0.1
# Iterations: 5000
# Polynomial Degree: 10
# Initial Parameters:
# [-0.4810533236270397, -0.040634123710833525, -0.027335477693520183, 0.11914904191370157, -0.21937067752863593, -0.39097528549678184, 0.13903272420564794, -0.44406552743292715, 0.1691023116969903, 0.4497472003739027, -0.04616089897247677]
# Final Parameters:
# [0.0006773210610022257, 8.112921909338665, -15.635439208568505, -5.59625816649138, 3.6868124546777112, 7.286658814713075, 7.227131675773385, 3.7493776549622626, 0.5819761566178673, -2.99149243873431, -7.003185372400324]
# Final Error:
# 0.1708672093736193
